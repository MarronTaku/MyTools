# %%
import os
import sys

# Colabの場合、ドライブをマウントしてマウント先を指定
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_PATH = '/content/drive/MyDrive/mounted/'
    print(f"Using Google Drive data path: {DATA_PATH}")
else:
    # ローカルの場合
    DATA_PATH = './data'
    print(f"Using local data path: {DATA_PATH}")
# Out:
# Mounted at /content/drive
# Using Google Drive data path: /content/drive/MyDrive/mounted/
